# %% [markdown]
# ### 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# Ans: Functions reduce the need for duplicate code. This makes code short.

# %% [markdown]
# ### 2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %% [markdown]
# Ans: The code in function runs when it is called

# %% [markdown]
# ### 3. What statement creates a function?

# %% [markdown]
# The def keyword statement creates a function.

# %% [markdown]
# ### 4. What is the difference between a function and a function call?

# %% [markdown]
# A function is a piece of code which enhanced the reusability and modularity of your program. It means that piece of code need not be written again.
# A function call means invoking or calling that function.

# %% [markdown]
# ### 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# There is one global scope, and a local scope is created whenever a function is called.

# %% [markdown]
# ### 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# A local variable retains its value until the next time the function is called. A local variable becomes undefined after the function call completes The local variable can be used outside the function any time after the function call completes.

# %% [markdown]
# ### 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
#  A return statement is used to end the execution of the function call and “returns” the result

# %% [markdown]
# ### 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# If a function doesn't specify a return value, it returns None.

# %% [markdown]
# ### 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# If you want to refer to a global variable in a function, you can use the global keyword to declare which variables are global.

# %% [markdown]
# ### 10. What is the data type of None?

# %% [markdown]
# The data type of None is Nonetype.

# %% [markdown]
# ### 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# This statement willimport areallyourpetsnamederic module.

# %% [markdown]
# ### 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# This function can be called with spam.bacon().

# %% [markdown]
# ### 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# We can use try except block.

# %% [markdown]
# ### 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# The code that may cause an error goes in the try clause. The code that executes if an error happens goes in the except clause.
