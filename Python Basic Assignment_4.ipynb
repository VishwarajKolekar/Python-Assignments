# %% [markdown]
# ### 1. What exactly is []?

# %% [markdown]
# This is an empty list.

# %% [markdown]
# ### 2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %% [markdown]
# spam[2] = 'hello'

# %% [markdown]
# # Let&#39;s pretend the spam includes the list [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;] for the next three queries.

# %% [markdown]
# ### 3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %% [markdown]
# Ans: The expression evaluates to spam[3], so the output will be 'd'

# %% [markdown]
# ### 4. What is the value of spam[-1]?

# %% [markdown]
# Ans: 'd'

# %% [markdown]
# ### 5. What is the value of spam[:2]?

# %% [markdown]
# Ans: ['a', 'b']

# %% [markdown]
# # Let&#39;s pretend bacon has the list [3.14, &#39;cat,&#39; 11, &#39;cat,&#39; True] for the next three questions.

# %% [markdown]
# ### 6. What is the value of bacon.index(&#39;cat&#39;)?

# %% [markdown]
# Ans: 1

# %% [markdown]
# ### 7. How does bacon.append(99) change the look of the list value in bacon?

# %% [markdown]
# Ans: It will append the value 99 at the end of the list. The list will loook as follows:
#     [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ### 8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?

# %% [markdown]
# Ans: The lst will look like: [3.14, 11, 'cat', True].

# %% [markdown]
# ### 9. What are the list concatenation and list replication operators?

# %% [markdown]
# Ans: The operator for list concatenation is +, while the operator for replication is *.

# %% [markdown]
# ### 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# Ans: With append() we can only add elements to list at last poistion, whereas with insert we can add element atany position inside the list.

# %% [markdown]
# ### 11. What are the two methods for removing items from a list?

# %% [markdown]
# Ans: del and remove() can be used to remove items from a list.

# %% [markdown]
# ### 12. Describe how list values and string values are identical.

# %% [markdown]
# Ans: Both lists and strings can be passed to len(), have indexes and slices, be used in for loops, be concatenated or replicated, and be used with the in and not in operators.

# %% [markdown]
# ### 13. What&#39;s the difference between tuples and lists?

# %% [markdown]
# Ans: Lists are mutable; they can have values added, removed, or changed. Tuples are immutable; they cannot be changed at all. Also, tuples are written using parentheses, ( and ), while lists use the square brackets, [ and ].

# %% [markdown]
# ### 14. How do you type a tuple value that only contains the integer 42?

# %% [markdown]
# Ans: (42,)

# %% [markdown]
# ### 15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %% [markdown]
# Ans: The tuple() and list() functions, respectively.

# %% [markdown]
# ### 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# Ans: They contain references to list values.

# %% [markdown]
# ### 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# Ans: The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
