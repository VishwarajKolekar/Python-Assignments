# %% [markdown]
# ### 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.* &#39;hello&#39; -87.8 - / + 6

# %% [markdown]
# Answer: Vales = 'hello', -87.8, 6
#         Expressions = *, -, / , +

# %% [markdown]
# ### 2. What is the difference between string and variable?

# %% [markdown]
# Variables are memory space used to store any information. String is a datatype which can store character sequences like words,  numbers enclosed in single or double quotes.

# %% [markdown]
# ### 3. Describe three different data types.

# %% [markdown]
# Int - Integer datatype is used to store whole numbers.
# Float - Floating point number dataset is used to store numbers with decimal places
# String -  String is a datatype which can store character sequences like words, numbers enclosed in single or double quotes.

# %% [markdown]
# ### 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# An expression is a combination of values and operators. All expressions evaluate (that is, reduce) to a single value.

# %% [markdown]
# ### 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# An expression evaluates to a single value. A statement does not.

# %% [markdown]
# ### 6. After running the following code, what does the variable bacon contain?
# ### bacon = 22
# ### bacon + 1

# %% [markdown]
# 22

# %% [markdown]
# ### 7. What should the values of the following two terms be? &#39;spam&#39; + &#39;spamspam&#39; &#39;spam&#39; * 3

# %% [markdown]
# Both will evaluate to 'spamspamspam'

# %% [markdown]
# ### 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Variables cannot begin with numbers

# %% [markdown]
# ### 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# int()<br>
# float()<br>
# str()<br>

# %% [markdown]
# ### 10. Why does this expression cause an error? How can you fix it? &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

# %% [markdown]
# We cannot add string object with integer typer object. <br> We should enclose 99 in quotes('99').
