# %% [markdown]
# ### 1. What does an empty dictionary&#39;s code look like?

# %% [markdown]
# Ans: Two curly brackets: {}

# %% [markdown]
# ### 2. What does a dictionary value with a key 'foo' and a value 42 look like?

# %% [markdown]
# Ans: {'foo': 42}

# %% [markdown]
# ### 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# Ans: The items stored in a dictionary are unordered, while the items in a list are ordered. The items in dictionary are accessed via keys and not via its position like in list.

# %% [markdown]
# ### 4. What happens if you try to access spam[&#39;foo&#39;] if spam is {&#39;bar&#39;: 100}?

# %% [markdown]
# Ans: You get a Keyerror.

# %% [markdown]
# ### 5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and &#39;cat&#39; in spam.keys()?

# %% [markdown]
# Ans: No difference. The in operator checks whether a value exists as a key in the dictionary.

# %% [markdown]
# ### 6. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and &#39;cat&#39; in spam.values()?

# %% [markdown]
# Ans: 'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %% [markdown]
# ### 7. What is a shortcut for the following code?
# ### if &#39;color&#39; not in spam:
# ### spam[&#39;color&#39;] = &#39;black&#39;

# %% [markdown]
# Ans: spam.setdefault('color', 'black')

# %% [markdown]
# ### 8. How do you &quot;pretty print&quot; dictionary values using which module and function?

# %% [markdown]
# Ans: pprint.pprint()
