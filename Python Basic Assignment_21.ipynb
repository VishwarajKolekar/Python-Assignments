# %% [markdown]
# ### 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 08-04-2022

# %% [markdown]
# ### 2. Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 08-04-2022

# %% [markdown]
# ### 3. Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-04-08 00:00:00

# %% [markdown]
# ### 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
#  Programming Assignment_7.ipynb
# 02_end_to_end_machine_learning_project.ipynb
# Admission_Prediction.csv
# Advertising.csv
# ai4i2020.csv
# application_log.txt
# Architcture file.zip
# array.log
# assignment8.log
# books.csv
# books.db
# car.data
# car.names
# class and object.ipynb
# Decision tree practical with random forest .ipynb
# DecisionTree.ipynb
# dt_model_1.png
# Dummy Destination
# FitBit data.csv
# glass (1).data
# glass.data
# google.txt
# imdb.sql
# ineuron.db
# ineuronsqllite.db
# joindb.db
# knn.pkl
# Linear Regression.ipynb
# linear_reg.sav
# Logistic Regression.ipynb
# MongoDB.ipynb
# person.db
# Position_Salaries.csv
# Programming Assignment_5.ipynb
# Programming Assignment_8.ipynb
# Programming Basic Assignment_1.ipynb
# Programming_Assignment4.ipynb
# Python Basic Assignemt_15.ipynb
# Python Basic Assignments_7.ipynb
# Python Basic Assignment_10.ipynb
# Python Basic Assignment_11.ipynb
# Python Basic assignment_12.ipynb
# Python Basic Assignment_13.ipynb
# Python Basic Assignment_14.ipynb
# Python Basic Assignment_16.ipynb
# Python Basic Assignment_17.ipynb
# Python Basic Assignment_18.ipynb
# Python Basic Assignment_19.ipynb
# Python Basic Assignment_20.ipynb
# Python Basic Assignment_21.ipynb
# Python Basic Assignment_3.ipynb
# Python Basic Assignment_4.ipynb
# Python Basic Assignment_6.ipynb
# Python Basic Assignment_8.ipynb
# Python Basic Assignment_9.ipynb
# Python Basic Assinment_5.ipynb
# Python.ipynb
# sql.ipynb
# SQLLITE.ipynb
# test.log
# test.txt
# test1.txt
# test2.log
# test2.txt
# test3.log
# today.txt
# university_records.csv
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# winequality-red.csv
# zoo.py
#  Programming Assignment_7-checkpoint.ipynb
# 02_end_to_end_machine_learning_project-checkpoint.ipynb
# class and object-checkpoint.ipynb
# Decision tree practical with random forest -checkpoint.ipynb
# DecisionTree-checkpoint.ipynb
# Linear Regression-checkpoint.ipynb
# Logistic Regression-checkpoint.ipynb
# MongoDB-checkpoint.ipynb
# Programming Assignment_5-checkpoint.ipynb
# Programming Assignment_8-checkpoint.ipynb
# Programming Basic Assignment_1-checkpoint.ipynb
# Programming_Assignment4-checkpoint.ipynb
# Python Basic Assignemt_15-checkpoint.ipynb
# Python Basic Assignments_7-checkpoint.ipynb
# Python Basic Assignment_10-checkpoint.ipynb
# Python Basic Assignment_11-checkpoint.ipynb
# Python Basic assignment_12-checkpoint.ipynb
# Python Basic Assignment_13-checkpoint.ipynb
# Python Basic Assignment_14-checkpoint.ipynb
# Python Basic Assignment_16-checkpoint.ipynb
# Python Basic Assignment_17-checkpoint.ipynb
# Python Basic Assignment_18-checkpoint.ipynb
# Python Basic Assignment_19-checkpoint.ipynb
# Python Basic Assignment_20-checkpoint.ipynb
# Python Basic Assignment_21-checkpoint.ipynb
# Python Basic Assignment_3-checkpoint.ipynb
# Python Basic Assignment_4-checkpoint.ipynb
# Python Basic Assignment_6-checkpoint.ipynb
# Python Basic Assignment_8-checkpoint.ipynb
# Python Basic Assignment_9-checkpoint.ipynb
# Python Basic Assinment_5-checkpoint.ipynb
# Python-checkpoint.ipynb
# sql-checkpoint.ipynb
# SQLLITE-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Untitled1-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Untitled3-checkpoint.ipynb
# housing.csv
# housing.tgz
# attribute_histogram_plots.png
# bad_visualization_plot.png
# better_visualization_plot.png
# housing_prices_scatterplot.png
# scatter_matrix_plot.png
# zoo.cpython-38.pyc

# %% [markdown]
# ### 5. Create a list of all of the files in your parent directory (minimum five files should be available)

# %%
import os 
os.listdir()
# Out:
# [' Programming Assignment_7.ipynb',
#  '.ipynb_checkpoints',
#  '02_end_to_end_machine_learning_project.ipynb',
#  'Admission_Prediction.csv',
#  'Advertising.csv',
#  'ai4i2020.csv',
#  'application_log.txt',
#  'Architcture file.zip',
#  'array.log',
#  'assignment8.log',
#  'books.csv',
#  'books.db',
#  'car.data',
#  'car.names',
#  'class and object.ipynb',
#  'datasets',
#  'Decision tree practical with random forest .ipynb',
#  'DecisionTree.ipynb',
#  'dt_model_1.png',
#  'Dummy Destination',
#  'End2End_housePrice',
#  'FitBit data.csv',
#  'glass (1).data',
#  'glass.data',
#  'google.txt',
#  'imdb.sql',
#  'ineuron.db',
#  'ineuronsqllite.db',
#  'joindb.db',
#  'knn.pkl',
#  'Linear Regression.ipynb',
#  'linear_reg.sav',
#  'Logistic Regression.ipynb',
#  'MongoDB.ipynb',
#  'person.db',
#  'Position_Salaries.csv',
#  'Programming Assignment_5.ipynb',
#  'Programming Assignment_8.ipynb',
#  'Programming Basic Assignment_1.ipynb',
#  'Programming_Assignment4.ipynb',
#  'Python Basic Assignemt_15.ipynb',
#  'Python Basic Assignments_7.ipynb',
#  'Python Basic Assignment_10.ipynb',
#  'Python Basic Assignment_11.ipynb',
#  'Python Basic assignment_12.ipynb',
#  'Python Basic Assignment_13.ipynb',
#  'Python Basic Assignment_14.ipynb',
#  'Python Basic Assignment_16.ipynb',
#  'Python Basic Assignment_17.ipynb',
#  'Python Basic Assignment_18.ipynb',
#  'Python Basic Assignment_19.ipynb',
#  'Python Basic Assignment_20.ipynb',
#  'Python Basic Assignment_21.ipynb',
#  'Python Basic Assignment_3.ipynb',
#  'Python Basic Assignment_4.ipynb',
#  'Python Basic Assignment_6.ipynb',
#  'Python Basic Assignment_8.ipynb',
#  'Python Basic Assignment_9.ipynb',
#  'Python Basic Assinment_5.ipynb',
#  'Python.ipynb',
#  'sql.ipynb',
#  'SQLLITE.ipynb',
#  'test.log',
#  'test.txt',
#  'test1.txt',
#  'test2.log',
#  'test2.txt',
#  'test3.log',
#  'today.txt',
#  'university_records.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'winequality-red.csv',
#  'zoo.py',
#  '__pycache__']

# %% [markdown]
# ### 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
# import multiprocessing
# import time 
# import random
# import datetime

# def procOne():
#     print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
#     time.sleep(random.randint(1,5))
#     print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
# def procTwo():
#     print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
#     time.sleep(random.randint(1,5))
#     print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

# def procThree():
#     print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
#     time.sleep(random.randint(1,5))
#     print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
# if __name__ == "__main__":    
#     p1 = multiprocessing.Process(target=procOne)
#     p2 = multiprocessing.Process(target=procTwo)
#     p3 = multiprocessing.Process(target=procThree)

#     p1.start()
#     p2.start()
#     p3.start()

#     p1.join()
#     p2.join()
#     p3.join()

# %%
# !python multi.py
# Out:
# Proc_two_Starttime -> 2022-04-08 13:12:58.040455
# Proc_two_Endtime -> 2022-04-08 13:12:59.042394
# Proc_two_Starttime -> 2022-04-08 13:12:58.041450
# Proc_two_Endtime -> 2022-04-08 13:12:59.042394
# Proc_one_Starttime -> 2022-04-08 13:12:58.037430
# Proc_one_Endtime -> 2022-04-08 13:13:02.041064

# %% [markdown]
# ### 7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('07/01/1999','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1999-01-07 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# ### 8. What day of the week was your day of birth?

# %%
my_dob.strftime("%A")
# Out:
# 'Thursday'

# %% [markdown]
# ### 9.When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
days=timedelta(days=10000)
str(my_dob.date()+days)
# Out:
# '2026-05-25'
